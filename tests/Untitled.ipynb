# %%
from langchain_groq import ChatGroq
from langchain_ollama import ChatOllama

# %%
generation_chat = [{
    "role": "system",
    "content": """You are a Python Programmer tasked with generating high quality code
    Your task is to generate the best possible code for the user. If the user provides critique,
    respond with a revised version of the previous code"""
}]

generation_chat.append({
    "role": "user",
    "content": "Generate C code for the merge sort algorithm" 
})

# %%
llm = ChatOllama(model="mistral",
                temperature=0)
# llm = ChatGroq(model="llama-3.3-70b-versatile",
#               api_key="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",
#               temperature=0)

# %%
response = llm.invoke(generation_chat)

# %%
print(response.content)
# Out:
#  Here's a simple implementation of Merge Sort in C. This version uses recursion and dynamic memory allocation for temporary arrays during the merging process.
#
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# void merge(int arr[], int left, int mid, int right) {
#     int n1 = mid - left + 1;
#     int n2 = right - mid;
#
#     int L[n1], R[n2];
#
#     for (int i = 0; i < n1; i++)
#         L[i] = arr[left + i];
#     for (int j = 0; j < n2; j++)
#         R[j] = arr[mid + 1 + j];
#
#     int i, j, k;
#     i = 0;
#     j = 0;
#     k = left;
#
#     while (i < n1 && j < n2) {
#         if (L[i] <= R[j]) {
#             arr[k] = L[i];
#             i++;
#         } else {
#             arr[k] = R[j];
#             j++;
#         }
#         k++;
#     }
#
#     while (i < n1) {
#         arr[k] = L[i];
#         i++;
#         k++;
#     }
#
#     while (j < n2) {
#         arr[k] = R[j];
#         j++;
#         k++;
#     }
# }
#
# ...

# %%
generation_chat.append({
    "role": "assistant",
    "content": response.content
})

# %%
reflection_chat = [{
    "role": "system",
    "content": "You are an experienced computer scientist, tasked with providing critique and recommendations for the provided code"
}]

reflection_chat.append({
    "role": "user",
    "content": response.content
})

response = llm.invoke(reflection_chat)
print(response.content)
# Out:
#  Your implementation of Merge Sort in C is well-structured and easy to understand. Here are a few recommendations for improvement:
#
# 1. Use `const` keyword for function parameters that do not need to be modified within the function. This can help prevent accidental modification of input parameters and make your code more readable. For example, you could change the signature of `mergeSort` function to:
#
# ```c
# void mergeSort(const int arr[], int left, int right);
# ```
#
# 2. Consider using `size_t` instead of `int` for array sizes and indices. This can help avoid potential issues with signed vs. unsigned integers when dealing with large arrays or index values.
#
# 3. In the `merge` function, you could use a single loop to copy elements from both L and R arrays into the original arr[] using a condition to check which element should be copied at each step. This would make the code slightly more concise:
#
# ```c
# for (int k = left; i < n1 && j < n2; k++) {
# ...

# %%
generation_chat.append({
    "role": "user",
    "content": response.content
})

response = llm.invoke(generation_chat)
print(response.content)
# Out:
#  Here's a revised version of the Merge Sort implementation in C with the suggested improvements:
#
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# // Const keyword for function parameters that do not need to be modified within the function
# void mergeSort(const int arr[], size_t left, size_t right);
#
# void merge(int arr[], size_t left, size_t mid, size_t right) {
#     size_t n1 = mid - left + 1;
#     size_t n2 = right - mid;
#
#     int L[n1], R[n2];
#
#     for (size_t i = 0; i < n1; i++)
#         L[i] = arr[left + i];
#     for (size_t j = 0; j < n2; j++)
#         R[j] = arr[mid + 1 + j];
#
#     size_t i = 0, j = 0, k = left;
#
#     while (i < n1 && j < n2) {
#         if (L[i] <= R[j]) {
#             arr[k++] = L[i++];
#         } else {
#             arr[k++] = R[j++];
#         }
#     }
#
#     while (i < n1) {
#         arr[k++] = L[i++];
#     }
#
#     while (j < n2) {
#         arr[k++] = R[j++];
#     }
# }
#
# ...
